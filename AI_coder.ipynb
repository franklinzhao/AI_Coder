# %% [markdown]
# This project a AI Coder. It can complete a whole project and output the whole finished program without human involve.

# %%
# %pip install crewai langchain_groq langchain_community llama_index llama_index.llms.fireworks langchain langchain_core
# Out:
# Requirement already satisfied: crewai in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (0.51.1)
# Requirement already satisfied: langchain_groq in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (0.1.9)
# Requirement already satisfied: langchain_community in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (0.2.11)
# Requirement already satisfied: llama_index in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (0.10.64)
# Requirement already satisfied: llama_index.llms.fireworks in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (0.1.8)
# Requirement already satisfied: langchain in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (0.2.12)
# Requirement already satisfied: langchain_core in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (0.2.31)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.4 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from crewai) (1.4.4)
# Requirement already satisfied: click<9.0.0,>=8.1.7 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from crewai) (8.1.7)
# Requirement already satisfied: embedchain<0.2.0,>=0.1.114 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from crewai) (0.1.120)
# Requirement already satisfied: instructor==1.3.3 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from crewai) (1.3.3)
# Requirement already satisfied: json-repair<0.26.0,>=0.25.2 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from crewai) (0.25.3)
# Requirement already satisfied: jsonref<2.0.0,>=1.1.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from crewai) (1.1.0)
# Requirement already satisfied: openai<2.0.0,>=1.13.3 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from crewai) (1.40.0)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.22.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from crewai) (1.26.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from crewai) (1.26.0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.22.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from crewai) (1.26.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.2 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from crewai) (2.8.2)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from crewai) (1.0.1)
# Requirement already satisfied: regex<2024.0.0,>=2023.12.25 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from crewai) (2023.12.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from instructor==1.3.3->crewai) (3.10.1)
# Requirement already satisfied: docstring-parser<0.17,>=0.16 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from instructor==1.3.3->crewai) (0.16)
# Requirement already satisfied: jiter<0.5.0,>=0.4.1 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from instructor==1.3.3->crewai) (0.4.2)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from instructor==1.3.3->crewai) (2.20.1)
# Requirement already satisfied: rich<14.0.0,>=13.7.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from instructor==1.3.3->crewai) (13.7.1)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.3 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from instructor==1.3.3->crewai) (8.5.0)
# Requirement already satisfied: typer<1.0.0,>=0.9.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from instructor==1.3.3->crewai) (0.12.3)
# Requirement already satisfied: groq<1,>=0.4.1 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from langchain_groq) (0.9.0)
# Requirement already satisfied: PyYAML>=5.3 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from langchain_community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from langchain_community) (2.0.32)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from langchain_community) (0.1.98)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from langchain_community) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from langchain_community) (2.32.3)
# Requirement already satisfied: llama-index-agent-openai<0.3.0,>=0.1.4 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama_index) (0.2.9)
# Requirement already satisfied: llama-index-cli<0.2.0,>=0.1.2 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama_index) (0.1.13)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.64 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama_index) (0.10.64)
# Requirement already satisfied: llama-index-embeddings-openai<0.2.0,>=0.1.5 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama_index) (0.1.11)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.2.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama_index) (0.2.7)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama_index) (0.9.48)
# Requirement already satisfied: llama-index-llms-openai<0.2.0,>=0.1.27 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama_index) (0.1.29)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.2.0,>=0.1.3 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama_index) (0.1.9)
# Requirement already satisfied: llama-index-program-openai<0.2.0,>=0.1.3 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama_index) (0.1.7)
# Requirement already satisfied: llama-index-question-gen-openai<0.2.0,>=0.1.2 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama_index) (0.1.3)
# Requirement already satisfied: llama-index-readers-file<0.2.0,>=0.1.4 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama_index) (0.1.33)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.1.2 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama_index) (0.1.6)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from langchain) (0.2.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from langchain_core) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from langchain_core) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from langchain_core) (4.12.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor==1.3.3->crewai) (2.3.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor==1.3.3->crewai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor==1.3.3->crewai) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor==1.3.3->crewai) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor==1.3.3->crewai) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor==1.3.3->crewai) (1.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: alembic<2.0.0,>=1.13.1 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (1.13.2)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.2 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (4.12.3)
# Requirement already satisfied: chromadb<0.5.0,>=0.4.24 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.4.24)
# Requirement already satisfied: cohere<6.0,>=5.3 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (5.8.0)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.26.1 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (1.62.0)
# Requirement already satisfied: gptcache<0.2.0,>=0.1.43 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.1.44)
# Requirement already satisfied: langchain-cohere<0.2.0,>=0.1.4 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.1.9)
# Requirement already satisfied: langchain-openai<0.2.0,>=0.1.7 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.1.21)
# Requirement already satisfied: mem0ai<0.0.10,>=0.0.9 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.0.9)
# Requirement already satisfied: posthog<4.0.0,>=3.0.2 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (3.5.0)
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (4.3.1)
# Requirement already satisfied: pysbd<0.4.0,>=0.3.4 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.3.4)
# Requirement already satisfied: schema<0.8.0,>=0.7.5 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.7.7)
# Requirement already satisfied: tiktoken<0.8.0,>=0.7.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.7.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from groq<1,>=0.4.1->langchain_groq) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from groq<1,>=0.4.1->langchain_groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from groq<1,>=0.4.1->langchain_groq) (0.27.0)
# Requirement already satisfied: sniffio in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from groq<1,>=0.4.1->langchain_groq) (1.3.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain_core) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.0->langchain_community) (3.10.6)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.64->llama_index) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.64->llama_index) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.64->llama_index) (2024.6.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.64->llama_index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.64->llama_index) (3.3)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.64->llama_index) (3.8.1)
# Requirement already satisfied: pandas in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.64->llama_index) (2.2.2)
# Requirement already satisfied: pillow>=9.0.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.64->llama_index) (10.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.64->llama_index) (4.66.5)
# Requirement already satisfied: wrapt in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-core<0.11.0,>=0.10.64->llama_index) (1.16.0)
# Requirement already satisfied: llama-cloud>=0.0.11 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-indices-managed-llama-cloud>=0.2.0->llama_index) (0.0.13)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama_index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.4.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from llama-index-readers-llama-parse>=0.1.2->llama_index) (0.4.9)
# Requirement already satisfied: importlib-metadata<=8.0.0,>=6.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from opentelemetry-api<2.0.0,>=1.22.0->crewai) (8.0.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai) (1.63.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.26.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai) (1.26.0)
# Requirement already satisfied: opentelemetry-proto==1.26.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai) (1.26.0)
# Requirement already satisfied: protobuf<5.0,>=3.19 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from opentelemetry-proto==1.26.0->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai) (4.25.4)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.47b0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from opentelemetry-sdk<2.0.0,>=1.22.0->crewai) (0.47b0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.2->crewai) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from requests<3,>=2->langchain_community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from requests<3,>=2->langchain_community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from requests<3,>=2->langchain_community) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from requests<3,>=2->langchain_community) (2024.7.4)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.0.3)
# Requirement already satisfied: Mako in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from alembic<2.0.0,>=1.13.1->embedchain<0.2.0,>=0.1.114->crewai) (1.3.5)
# Requirement already satisfied: soupsieve>1.2 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from beautifulsoup4<5.0.0,>=4.12.2->embedchain<0.2.0,>=0.1.114->crewai) (2.5)
# Requirement already satisfied: build>=1.0.3 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (1.2.1)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.112.0)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.30.5)
# Requirement already satisfied: pulsar-client>=3.1.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (3.5.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (1.18.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (1.26.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.47b0)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.15.2)
# Requirement already satisfied: pypika>=0.48.9 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (1.65.4)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (4.2.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (30.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (4.1.0)
# Requirement already satisfied: boto3<2.0.0,>=1.34.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (1.34.160)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (1.9.5)
# Requirement already satisfied: httpx-sse==0.4.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (0.4.0)
# Requirement already satisfied: parameterized<0.10.0,>=0.9.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (0.9.0)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (2.32.0.20240712)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (2.19.1)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (2.33.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (1.24.0)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (2.18.2)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (3.25.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (1.12.5)
# Requirement already satisfied: shapely<3.0.0dev in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (2.0.5)
# Requirement already satisfied: cachetools in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from gptcache<0.2.0,>=0.1.43->embedchain<0.2.0,>=0.1.114->crewai) (5.4.0)
# Requirement already satisfied: httpcore==1.* in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain_groq) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain_groq) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from importlib-metadata<=8.0.0,>=6.0->opentelemetry-api<2.0.0,>=1.22.0->crewai) (3.19.2)
# Requirement already satisfied: langchain-experimental>=0.0.6 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.114->crewai) (0.0.64)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.114->crewai) (0.9.0)
# Requirement already satisfied: qdrant-client<2.0.0,>=1.9.1 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from mem0ai<0.0.10,>=0.0.9->embedchain<0.2.0,>=0.1.114->crewai) (1.11.0)
# Requirement already satisfied: joblib in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.64->llama_index) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.64->llama_index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.64->llama_index) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.64->llama_index) (2024.1)
# Requirement already satisfied: six>=1.5 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.114->crewai) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.114->crewai) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.114->crewai) (2.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from rich<14.0.0,>=13.7.0->instructor==1.3.3->crewai) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from rich<14.0.0,>=13.7.0->instructor==1.3.3->crewai) (2.18.0)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from typer<1.0.0,>=0.9.0->instructor==1.3.3->crewai) (1.5.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Requirement already satisfied: botocore<1.35.0,>=1.34.160 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from boto3<2.0.0,>=1.34.0->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (1.34.160)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from boto3<2.0.0,>=1.34.0->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from boto3<2.0.0,>=1.34.0->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (0.10.2)
# Requirement already satisfied: pyproject_hooks in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from build>=1.0.3->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (1.1.0)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from fastapi>=0.95.2->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.37.2)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (1.62.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (4.9)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (2.7.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (0.13.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (1.5.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (3.2.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.7.0->instructor==1.3.3->crewai) (0.1.2)
# Requirement already satisfied: coloredlogs in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (24.3.25)
# Requirement already satisfied: sympy in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (1.13.1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.47b0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.47b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.47b0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.47b0)
# Requirement already satisfied: opentelemetry-util-http==0.47b0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.47b0)
# Requirement already satisfied: setuptools>=16.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.47b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (72.1.0)
# Requirement already satisfied: asgiref~=3.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from opentelemetry-instrumentation-asgi==0.47b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (3.8.1)
# Requirement already satisfied: grpcio-tools>=1.41.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from qdrant-client<2.0.0,>=1.9.1->mem0ai<0.0.10,>=0.0.9->embedchain<0.2.0,>=0.1.114->crewai) (1.62.3)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from qdrant-client<2.0.0,>=1.9.1->mem0ai<0.0.10,>=0.0.9->embedchain<0.2.0,>=0.1.114->crewai) (2.10.1)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from tokenizers>=0.13.2->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.24.5)
# Requirement already satisfied: httptools>=0.5.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.6.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.22.0)
# Requirement already satisfied: websockets>=10.4 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (12.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from Mako->alembic<2.0.0,>=1.13.1->embedchain<0.2.0,>=0.1.114->crewai) (2.1.5)
# Requirement already satisfied: h2<5,>=3 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.0.10,>=0.0.9->embedchain<0.2.0,>=0.1.114->crewai) (4.1.0)
# Requirement already satisfied: filelock in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (3.15.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (0.6.0)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from sympy->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (1.3.0)
# Requirement already satisfied: hyperframe<7,>=6.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.0.10,>=0.0.9->embedchain<0.2.0,>=0.1.114->crewai) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in /Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.0.10,>=0.0.9->embedchain<0.2.0,>=0.1.114->crewai) (4.0.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
"""
Sample Project Description:
project 1.
I want to build a snake game, the snake will grow in length after it eat foods. the player use arrow to control its movement.
the objective is not to crash to walls,otherwise the player will lose. press q to quit the game. press s to stop the game.

project 2.
I want to build a calculator program , it will have add, minus, multipy, division, exponentiation, logarithms methods.
The program has error handling mechanism by providing informative error messages. It also implemented unit tests to ensure the
correctness of the calculatior's output.

project 3.
I want to build a tic tac toe game with python, it will have a computer player and a human player.
The computer player will make move by strategy base on Minimax algorithm, so it will make the best move,
maximize its chance to win.

"""
import os
from textwrap import dedent
from crewai import Agent, Task, Crew, Process
from langchain_groq import ChatGroq
from langchain_community.llms import Ollama
import random
from llama_index.llms.fireworks import Fireworks
import os

os.environ["GROQ_API_KEY"] = "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"
os.environ['FIREWORKS_API_KEY'] = '8nozAPErfL1PgACJgLIsUzKFPgGqabQGAPJ4z0VogUeiZhSb' # get a free key at https://fireworks.ai/api-keys
groq_hosted_llama = ChatGroq(
    model="llama-3.1-70b-versatile", #gemma2-9b-it
    # model="whisper-large-v3", #gemma2-9b-it
    # model="llama-3.1-8b-instant", #gemma2-9b-it
    temperature=1,
    max_tokens=1024,
    stop=None,
)

firework_hosted_llama = Fireworks(model="accounts/fireworks/models/llama-v3p1-405b-instruct", temperature=0)# localllm = Ollama(model="codestral:latest")#llama3.1:8b
llama8b_local = Ollama(model="llama3.1:8b")#llama3.1:8b

llm = groq_hosted_llama
# Setup evn设置环境变量，
os.environ["OPENAI_API_BASE"] = 'http://localhost:3000/'
os.environ["OPENAI_MODEL_NAME"] ="llama-3.1-70b-versatile" # 'codestral:latest'  # Adjust based on available model
os.environ["OPENAI_API_KEY"] ='ollama' #"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" #'ollama'

# Get user inputs
# project_name = input("Please provide a project name, no space and length is within 10 characters.\n")
# project_description = input("What is the program you would like to build? Please provide detailed description of the program and its requirements.")
project_name = "tictactoe"
project_description = ''' I want to build a tic tac toe game with python, it will have a computer player and a human player.
The computer player will make move by strategy base on Minimax algorithm, so it will make the best move,
maximize its chance to win.'''
code_language = "python" #input("what's the language of coding?")

# Define an Agent
senior_engineer_agent = Agent(
    llm=llm,
    role='Senior Software Engineer',
    goal='Create software as needed',
    backstory=dedent("""Instructions
                        You are a Senior Software Engineer at a leading tech think tank.
                        Your expertise in programming in {code_language}. and do your best to
                        produce perfect code, please use try catch for the main logic for any exceptions. """),
    allow_delegation=False,
    verbose=True
)

# Define an agent
qa_engineer_agent = Agent(
    llm=llm,
    role='Software Quality Control Engineer',
    goal='create prefect code, by analizing the code that is given for errors',
    backstory=dedent("""\
                        You are a software engineer that specializes in checking code
                        for errors. You have an eye for detail and a knack for finding
                        hidden bugs.
                        You check for missing imports, variable declarations, mismatched
                        brackets and syntax errors.
                        You also check for security vulnerabilities, and logic errors, and if it used try catch. """),
    allow_delegation=False,
    verbose=True
)

# Define an agent
chief_qa_engineer_agent = Agent(
    llm=llm,
    role='Chief Software Quality Control Engineer',
    goal='Ensure that the code does the job that it is supposed to do',
    backstory=dedent("""\
                        You feel that programmers always do only half of the job, so you are
                        super dedicate to make high quality code and if it used try catch."""),
    allow_delegation=True,
    verbose=True
)

# Define task
code_task = Task(
    llm=llm,
    description=dedent(f"""You will create a program using {code_language}, these are the instructions:

                            Instructions
                            ------------
                        {project_description}

                            Your Final answer must be the full {code_language} code, only the {code_language} code and nothing else and
                            and it should used try catch.
  			        """),
    expected_output="A complete {code_language} code implementing all specified mechanics, fully functional and commented.",
    agent=senior_engineer_agent
)

review_task = Task(
    llm=llm,
    description=dedent(f"""\
                            You are helping create a program using {code_language}, these are the instructions:

                            Instructions
                            ------------
                            {project_description}

                            Using the code you got, check for errors. Check for logic errors,
                            syntax errors, missing imports, variable declarations, mismatched brackets,
                            and security vulnerabilities.

                            Your Final answer must be the full {code_language} code, only the {code_language} code and nothing else
                            and it should used try catch.
  			        """),
    expected_output="An error-checked and corrected {code_language} code, ensuring no syntax, logical, or security flaws are present and it should used try catch.",
    agent=qa_engineer_agent
)

evaluate_task = Task(
    llm=llm,
    description=dedent(f"""\
                            You are helping create a program using {code_language}, these are the instructions:

                            Instructions
                            ------------
                            {project_description}

                            You will look over the code to insure that it is complete and
                            does the job that it is supposed to do.

                            Your Final answer must be the full {code_language} code, only the {code_language} code and nothing else
                            and it should used try catch.
			            """),
    expected_output="A finalized {code_language} code of the program that is reviewed for completeness, functionality, and optimization.",
    agent=chief_qa_engineer_agent
)

# Define the team
crew = Crew(
  agents=[senior_engineer_agent, qa_engineer_agent,chief_qa_engineer_agent],
  tasks=[code_task, review_task,evaluate_task],
  verbose=2, # You can set it to 1 or 2 to different logging levels
)

# The team to start work
final_output_code = crew.kickoff()

# Print output
print("\n\n########################")
print("## Here is the final output code of result")
print("########################\n")
print("final code for the project:")
print(final_output_code)

#save it to local folder
# Create 'result' folder if it doesn't exist
result_folder = os.path.join(os.getcwd(), 'result')
os.makedirs(result_folder, exist_ok=True)

# Define the full path where the code file will be saved
filename = os.path.join(result_folder, f"{project_name}_{str(random.randint(1, 10))}.py")

# Write the code to the .py file in the 'result' folder
with open(filename, "w") as file:
    final_result=str.replace(str(final_output_code),"```","#```")
    # print("final"+final_result)
    file.write(final_result)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 20
#      18 import os
#      19 from textwrap import dedent
# ---> 20 from crewai import Agent, Task, Crew, Process
#      21 from langchain_groq import ChatGroq
#      22 from langchain_community.llms import Ollama
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/crewai/__init__.py:1
# ----> 1 from crewai.agent import Agent
#       2 from crewai.crew import Crew
#       3 from crewai.pipeline import Pipeline
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/crewai/agent.py:13
#      10 from langchain_openai import ChatOpenAI
#      11 from pydantic import Field, InstanceOf, PrivateAttr, model_validator
# ---> 13 from crewai.agents import CacheHandler, CrewAgentExecutor, CrewAgentParser
#      14 from crewai.agents.agent_builder.base_agent import BaseAgent
#      15 from crewai.memory.contextual.contextual_memory import ContextualMemory
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/crewai/agents/__init__.py:2
#       1 from .cache.cache_handler import CacheHandler
# ----> 2 from .executor import CrewAgentExecutor
#       3 from .parser import CrewAgentParser
#       4 from .tools_handler import ToolsHandler
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/crewai/agents/executor.py:7
#       3 from typing import Any, Dict, Iterator, List, Literal, Optional, Tuple, Union
#       4 import click
# ----> 7 from langchain.agents import AgentExecutor
#       8 from langchain.agents.agent import ExceptionTool
#       9 from langchain.callbacks.manager import CallbackManagerForChainRun
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/langchain/agents/__init__.py:48
#      39 from langchain.agents.agent import (
#      40     Agent,
#      41     AgentExecutor,
#    (...)
#      45     LLMSingleActionAgent,
#      46 )
#      47 from langchain.agents.agent_iterator import AgentExecutorIterator
# ---> 48 from langchain.agents.agent_toolkits.vectorstore.base import (
#      49     create_vectorstore_agent,
#      50     create_vectorstore_router_agent,
#      51 )
#      52 from langchain.agents.agent_types import AgentType
#      53 from langchain.agents.conversational.base import ConversationalAgent
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/langchain/agents/agent_toolkits/vectorstore/base.py:14
#       9 from langchain.agents.agent_toolkits.vectorstore.prompt import PREFIX, ROUTER_PREFIX
#      10 from langchain.agents.agent_toolkits.vectorstore.toolkit import (
#      11     VectorStoreRouterToolkit,
#      12     VectorStoreToolkit,
#      13 )
# ---> 14 from langchain.agents.mrkl.base import ZeroShotAgent
#      15 from langchain.chains.llm import LLMChain
#      18 def create_vectorstore_agent(
#      19     llm: BaseLanguageModel,
#      20     toolkit: VectorStoreToolkit,
#    (...)
#      25     **kwargs: Any,
#      26 ) -> AgentExecutor:
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/langchain/agents/mrkl/base.py:20
#      18 from langchain.agents.utils import validate_tools_single_input
#      19 from langchain.chains import LLMChain
# ---> 20 from langchain.tools.render import render_text_description
#      23 class ChainConfig(NamedTuple):
#      24     """Configuration for a chain to use in MRKL system.
#      25
#      26     Parameters:
#    (...)
#      29         action_description: Description of the action.
#      30     """
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/langchain/tools/render.py:9
#       1 """Different methods for rendering Tools to be passed to LLMs.
#       2
#       3 Depending on the LLM you are using and the prompting strategy you are using,
#       4 you may want Tools to be rendered in a different way.
#       5 This module contains various ways to render tools.
#       6 """
#       8 # For backwards compatibility
# ----> 9 from langchain_core.tools import (
#      10     ToolsRenderer,
#      11     render_text_description,
#      12     render_text_description_and_args,
#      13 )
#      14 from langchain_core.utils.function_calling import (
#      15     format_tool_to_openai_function,
#      16     format_tool_to_openai_tool,
#      17 )
#      19 __all__ = [
#      20     "ToolsRenderer",
#      21     "render_text_description",
#    (...)
#      24     "format_tool_to_openai_function",
#      25 ]
#
# ImportError: cannot import name 'ToolsRenderer' from 'langchain_core.tools' (/Users/franklinzhao/.pyenv/versions/3.12.4/lib/python3.12/site-packages/langchain_core/tools/__init__.py)
